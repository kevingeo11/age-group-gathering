# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from keras.models import Sequential
from keras import Model
from keras import Input
from keras.utils import plot_model
from keras.layers import concatenate
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
from keras import backend as K

from sklearn.preprocessing import OneHotEncoder

import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import scipy.io as sio
import os

# %matplotlib inline

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
imgloc_train = []
label_train = []

imgloc_val = []
label_val = []

for dirname, _, filenames in os.walk('..\Train\Adults'):
    for filename in filenames[:-50]:
        imgloc_train.append((os.path.join(dirname, filename)))
        label_train.append(0)
    for filename in filenames[-50:]:
        imgloc_val.append((os.path.join(dirname, filename)))
        label_val.append(0)
        
for dirname, _, filenames in os.walk('..\Train\Teenagers'):
    for filename in filenames[:-50]:
        imgloc_train.append((os.path.join(dirname, filename)))
        label_train.append(1)
    for filename in filenames[-50:]:
        imgloc_val.append((os.path.join(dirname, filename)))
        label_val.append(1)
        
for dirname, _, filenames in os.walk('..\Train\Toddler'):
    for filename in filenames[:-50]:
        imgloc_train.append((os.path.join(dirname, filename)))
        label_train.append(2)
    for filename in filenames[-50:]:
        imgloc_val.append((os.path.join(dirname, filename)))
        label_val.append(2)

# %%
img_train = []
img_val = []

for i in range(0, len(imgloc_train)):
    img1 = cv2.imread(imgloc_train[i],1)
    img2 = np.array(img1)
    img2 = cv2.resize(img2,(128,128))
    img_train.append(cv2.cvtColor(img2,cv2.COLOR_BGR2RGB))
    
for i in range(0, len(imgloc_val)):
    img1 = cv2.imread(imgloc_val[i],1)
    img2 = np.array(img1)
    img2 = cv2.resize(img2,(128,128))
    img_val.append(cv2.cvtColor(img2,cv2.COLOR_BGR2RGB))

# %%
img_train = np.array(img_train)
label_train = np.array(label_train).reshape(-1,1)

img_val = np.array(img_val)
label_val = np.array(label_val).reshape(-1,1)

# %%
i = 5
plt.imshow(img_train[i])
plt.imshow(img_val[i])

# %%
img_train.shape
# Out:
# (2439, 128, 128, 3)

# %%
x_train = img_train/255
x_val = img_val/255

# %%
enc_y = OneHotEncoder(handle_unknown='ignore')
enc_y.fit(label_train)
y_train = enc_y.transform(label_train).toarray()
y_val = enc_y.transform(label_val).toarray()

# %%
x_train.shape
# Out:
# (2439, 128, 128, 3)

# %%
y_train.shape
# Out:
# (2439, 3)

# %%
model = Sequential()
model.add(Conv2D(6, kernel_size=(5, 5), strides=(1, 1), activation='relu',input_shape=x_train[0].shape))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Conv2D(16, kernel_size=(5, 5), strides=(1, 1), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Conv2D(32, kernel_size=(5, 5), strides=(1, 1), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(3, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 124, 124, 6)       456
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 62, 62, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 58, 58, 16)        2416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 29, 29, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 32)        12832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              4719616
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 4,998,491
# Trainable params: 4,998,491
# Non-trainable params: 0
# _________________________________________________________________

# %%
adam = Adam(learning_rate = 0.0001)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics = ['categorical_accuracy'])

# %%
es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=50)
mc = ModelCheckpoint('LeNet.h5', monitor='val_loss', mode='min', save_best_only=True, verbose=1)
callbacks = [es, mc]

history = model.fit(
    x = x_train,
    y = y_train,
    epochs=20, batch_size=32,
    validation_data = (x_val,y_val),
    verbose = 1, callbacks = callbacks)
# Out:
# Epoch 1/20
# 77/77 [==============================] - ETA: 0s - loss: 1.0945 - categorical_accuracy: 0.3719
# Epoch 00001: val_loss improved from inf to 1.05737, saving model to LeNet.h5
# 77/77 [==============================] - 36s 473ms/step - loss: 1.0945 - categorical_accuracy: 0.3719 - val_loss: 1.0574 - val_categorical_accuracy: 0.4200
# Epoch 2/20
# 77/77 [==============================] - ETA: 0s - loss: 1.0393 - categorical_accuracy: 0.4506
# Epoch 00002: val_loss improved from 1.05737 to 1.00901, saving model to LeNet.h5
# 77/77 [==============================] - 32s 420ms/step - loss: 1.0393 - categorical_accuracy: 0.4506 - val_loss: 1.0090 - val_categorical_accuracy: 0.4667
# Epoch 3/20
# 77/77 [==============================] - ETA: 0s - loss: 1.0092 - categorical_accuracy: 0.4678
# Epoch 00003: val_loss improved from 1.00901 to 0.98370, saving model to LeNet.h5
# 77/77 [==============================] - 31s 407ms/step - loss: 1.0092 - categorical_accuracy: 0.4678 - val_loss: 0.9837 - val_categorical_accuracy: 0.5733
# Epoch 4/20
# 77/77 [==============================] - ETA: 0s - loss: 0.9661 - categorical_accuracy: 0.5277
# Epoch 00004: val_loss improved from 0.98370 to 0.96376, saving model to LeNet.h5
# 77/77 [==============================] - 30s 388ms/step - loss: 0.9661 - categorical_accuracy: 0.5277 - val_loss: 0.9638 - val_categorical_accuracy: 0.5333
# Epoch 5/20
# 77/77 [==============================] - ETA: 0s - loss: 0.9193 - categorical_accuracy: 0.5666
# Epoch 00005: val_loss improved from 0.96376 to 0.92956, saving model to LeNet.h5
# 77/77 [==============================] - 30s 393ms/step - loss: 0.9193 - categorical_accuracy: 0.5666 - val_loss: 0.9296 - val_categorical_accuracy: 0.5733
# Epoch 6/20
# 77/77 [==============================] - ETA: 0s - loss: 0.8732 - categorical_accuracy: 0.6154
# Epoch 00006: val_loss did not improve from 0.92956
# 77/77 [==============================] - 31s 404ms/step - loss: 0.8732 - categorical_accuracy: 0.6154 - val_loss: 0.9609 - val_categorical_accuracy: 0.5333
# Epoch 7/20
# 77/77 [==============================] - ETA: 0s - loss: 0.8436 - categorical_accuracy: 0.6130
# Epoch 00007: val_loss did not improve from 0.92956
# 77/77 [==============================] - 30s 389ms/step - loss: 0.8436 - categorical_accuracy: 0.6130 - val_loss: 0.9660 - val_categorical_accuracy: 0.5267
# Epoch 8/20
# 77/77 [==============================] - ETA: 0s - loss: 0.7896 - categorical_accuracy: 0.6511
# Epoch 00008: val_loss did not improve from 0.92956
# 77/77 [==============================] - 31s 401ms/step - loss: 0.7896 - categorical_accuracy: 0.6511 - val_loss: 0.9643 - val_categorical_accuracy: 0.5200
# Epoch 9/20
# 77/77 [==============================] - ETA: 0s - loss: 0.7133 - categorical_accuracy: 0.7085
# Epoch 00009: val_loss did not improve from 0.92956
# 77/77 [==============================] - 31s 401ms/step - loss: 0.7133 - categorical_accuracy: 0.7085 - val_loss: 0.9889 - val_categorical_accuracy: 0.5133
# Epoch 10/20
# 77/77 [==============================] - ETA: 0s - loss: 0.5977 - categorical_accuracy: 0.7749
# Epoch 00010: val_loss did not improve from 0.92956
# 77/77 [==============================] - 35s 452ms/step - loss: 0.5977 - categorical_accuracy: 0.7749 - val_loss: 1.0625 - val_categorical_accuracy: 0.5333
# Epoch 11/20
# 77/77 [==============================] - ETA: 0s - loss: 0.5013 - categorical_accuracy: 0.8208
# Epoch 00011: val_loss did not improve from 0.92956
# 77/77 [==============================] - 33s 424ms/step - loss: 0.5013 - categorical_accuracy: 0.8208 - val_loss: 1.1639 - val_categorical_accuracy: 0.5267
# Epoch 12/20
# 77/77 [==============================] - ETA: 0s - loss: 0.3826 - categorical_accuracy: 0.8774
# Epoch 00012: val_loss did not improve from 0.92956
# 77/77 [==============================] - 33s 423ms/step - loss: 0.3826 - categorical_accuracy: 0.8774 - val_loss: 1.1570 - val_categorical_accuracy: 0.5067
# Epoch 13/20
# 77/77 [==============================] - ETA: 0s - loss: 0.2832 - categorical_accuracy: 0.9196
# Epoch 00013: val_loss did not improve from 0.92956
# 77/77 [==============================] - 31s 399ms/step - loss: 0.2832 - categorical_accuracy: 0.9196 - val_loss: 1.2624 - val_categorical_accuracy: 0.5400
# Epoch 14/20
# 77/77 [==============================] - ETA: 0s - loss: 0.1965 - categorical_accuracy: 0.9524
# Epoch 00014: val_loss did not improve from 0.92956
# 77/77 [==============================] - 31s 396ms/step - loss: 0.1965 - categorical_accuracy: 0.9524 - val_loss: 1.2569 - val_categorical_accuracy: 0.5400
# Epoch 15/20
# 77/77 [==============================] - ETA: 0s - loss: 0.1391 - categorical_accuracy: 0.9738
# Epoch 00015: val_loss did not improve from 0.92956
# 77/77 [==============================] - 36s 469ms/step - loss: 0.1391 - categorical_accuracy: 0.9738 - val_loss: 1.3795 - val_categorical_accuracy: 0.5533
# Epoch 16/20
# 77/77 [==============================] - ETA: 0s - loss: 0.1009 - categorical_accuracy: 0.9807
# Epoch 00016: val_loss did not improve from 0.92956
# 77/77 [==============================] - 34s 447ms/step - loss: 0.1009 - categorical_accuracy: 0.9807 - val_loss: 1.6982 - val_categorical_accuracy: 0.5133
# Epoch 17/20
# 77/77 [==============================] - ETA: 0s - loss: 0.0807 - categorical_accuracy: 0.9881
# Epoch 00017: val_loss did not improve from 0.92956
# 77/77 [==============================] - 36s 468ms/step - loss: 0.0807 - categorical_accuracy: 0.9881 - val_loss: 1.6278 - val_categorical_accuracy: 0.5200
# Epoch 18/20
# 77/77 [==============================] - ETA: 0s - loss: 0.0643 - categorical_accuracy: 0.9910
# Epoch 00018: val_loss did not improve from 0.92956
# 77/77 [==============================] - 33s 425ms/step - loss: 0.0643 - categorical_accuracy: 0.9910 - val_loss: 1.6193 - val_categorical_accuracy: 0.5000
# Epoch 19/20
# 77/77 [==============================] - ETA: 0s - loss: 0.0551 - categorical_accuracy: 0.9918
# Epoch 00019: val_loss did not improve from 0.92956
# 77/77 [==============================] - 35s 449ms/step - loss: 0.0551 - categorical_accuracy: 0.9918 - val_loss: 2.0151 - val_categorical_accuracy: 0.5133
# Epoch 20/20
# 77/77 [==============================] - ETA: 0s - loss: 0.0702 - categorical_accuracy: 0.9897
# Epoch 00020: val_loss did not improve from 0.92956
# 77/77 [==============================] - 32s 409ms/step - loss: 0.0702 - categorical_accuracy: 0.9897 - val_loss: 1.8006 - val_categorical_accuracy: 0.5067

# %%
model = load_model('LeNet.h5')

# %%
plt.figure()
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(history.history['categorical_accuracy'], label='train')
plt.plot(history.history['val_categorical_accuracy'], label='val')
plt.legend()
plt.show()

# %%
model.evaluate(x_val,y_val)
# Out:
# 5/5 [==============================] - 1s 103ms/step - loss: 0.9296 - categorical_accuracy: 0.5733
# [0.9295608401298523, 0.5733333230018616]

# %%
ymodel = model.predict(x_val)
ymodel = enc_y.inverse_transform(ymodel)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import precision_recall_fscore_support

# %%
confusion_matrix(label_val,ymodel)
# Out:
# array([[36,  9,  5],
#        [24, 15, 11],
#        [ 9,  6, 35]], dtype=int64)

# %%
f1_score(label_val,ymodel,average='weighted')
# Out:
# 0.5577037745791386

# %%
precision_recall_fscore_support(label_val,ymodel)
# Out:
# (array([0.52173913, 0.5       , 0.68627451]),
#  array([0.72, 0.3 , 0.7 ]),
#  array([0.60504202, 0.375     , 0.69306931]),
#  array([50, 50, 50], dtype=int64))
